# %% [markdown]
# <center>
#     <h1>ME 278: Assignment 02</h1>
#     <h3>Date: $25^{th}$ September, 2024 <br> Due date: $06^{th}$ October, 2024 (till 23:59 Hrs)</h3>

# %% [markdown]
# # Instructions:
# 1. You can use IDE of your choice for coding: Jupyter lab/ Jupyter notebook/ VS Code/ any other. \
# **Only " .ipynb "  file will be accepted for grading, no other file type will be considered.**
# 2. You must upload **only one .ipynb file.** For pen paper based work, upload the images in the same .ipynb file, no separate file will be considered for evaluation.
# 3. Please follow the format for name of .ipynb file as: \
# ME278_Assignment1_\<Your name>_<Last 5 digits of SR No.>.ipynb \
# Eg. ME278_Assignment1_Sarvesh_12345.ipynb

# %% [markdown]
# ### Question 1
#
# #### Introduction:
# Singular Value Decomposition (SVD), a matrix factorization technique has an important role in machine learning based applications. Everytime we visit Amazon, Youtube, Netflix, or any other e-commerce websites; we see some recommendations for the products, videos or movies etc. based on our previous views or with highest ratings by users. One of the appplications of SVD is to build these recommender systems with dimensionality reduction.
#
# Let's explore SVD's application to a movie recommendation system.\
# Through a small learning exercise, let's see why SVD works for movie rating prediction in recommender systems.
#
# #### Question:
# The following table is a movie-rating matrix. Each row of a matrix represents a user(U1, U2, ....,U6) and each column represents a movie name(M1, M2, ...., M5). The entries of the matrix are ratings given by user for the corresponding movie. (Rating:0 is a worst movie. Rating:5 is the best movie)
#
# </p>
# <table>
#     <tr>
#         <th text-align=center></th>
#         <th text-align=center>M1</th>
#         <th text-align=center>M2</th>
#         <th text-align=center>M3</th>
#         <th text-align=center>M4</th>
#         <th text-align=center>M5</th>
#     </tr>
#     <tr>
#         <td text-align=center><b>$U1$</b></td>
#         <td text-align=center>5</td>
#         <td text-align=center>5</td>
#         <td text-align=center>4</td>
#         <td text-align=center>1</td>
#         <td text-align=center>1</td>
#     </tr>
#     <tr>
#         <td text-align=center><b>$U2$</b></td>
#         <td text-align=center>4</td>
#         <td text-align=center>5</td>
#         <td text-align=center>5</td>
#         <td text-align=center>0</td>
#         <td text-align=center>1</td>
#     </tr>
#     <tr>
#         <td text-align=center><b>$U3$</b></td>
#         <td text-align=center>5</td>
#         <td text-align=center>4</td>
#         <td text-align=center>5</td>
#         <td text-align=center>1</td>
#         <td text-align=center>0</td>
#     </tr>
#     <tr>
#         <td text-align=center><b>$U4$</b></td>
#         <td text-align=center>4</td>
#         <td text-align=center>5</td>
#         <td text-align=center>4</td>
#         <td text-align=center>1</td>
#         <td text-align=center>1</td>
#     </tr>
#     <tr>
#         <td text-align=center><b>$U5$</b></td>
#         <td text-align=center>0</td>
#         <td text-align=center>1</td>
#         <td text-align=center>2</td>
#         <td text-align=center>5</td>
#         <td text-align=center>5</td>
#     </tr>
#     <tr>
#         <td text-align=center><b>$U6$</b></td>
#         <td text-align=center>1</td>
#         <td text-align=center>2</td>
#         <td text-align=center>1</td>
#         <td text-align=center>4</td>
#         <td text-align=center>5</td>
#     </tr>
# </table>
#
# The above matrix has 2 types of movies: Action and Comedy. \
# The movies M1, M2 and M3 are Action type of movies. Movies M4 and M5 are Comedy type movies.
#
# 1. **[0.5 points]** **SVD:** Factorize above movie-rating matrix using SVD into matrices $U$, $\Sigma$, $V^{T}$. (Use Numpy to perform SVD)
#
# 2. **[0.5 points]** **Analyze the matrices:** For the obtained above matrices $U$, $\Sigma$, $V^{T}$, comment what these matrices represents in terms of user, movies, movie type and movie ratings?
#
# 4. **[1 points]** Reduce the matrix dimensionality based on imporatant singular values considering the genre of movies in the question, say this obtained reduced matrix is matrix A. Comapre and comment the reduced matrix (A) with the original movie-rating matrix given in the question.
#
# 3. **Rating prediction:** \
# **a) [1 points]** There is a new user "UserA", who gave ratings only for movies M1 and M4 as 5 and 1, respectively. Can you predict his ratings for the remaining movies M2, M3 and M5 using the reduced matrix A obtained in the above part? (**Note:** To predict the remaining ratings, consider the initial guess rating as 3)\
# Is the new user "UserA" a fan of Action movies or Comedy movies?\
# **b) [1 points]**  One more new user "UserB", gave ratings only for movies M2 and M5 as 1 and 5, respectively.
# Can you predict his ratings for the remaining movies M1, M3 and M4 using SVD? (**Note:** Again, to predict the remaining ratings, consider the initial guess rating as 3) \
# Is the new user "UserB" a fan of Action movies or Comedy movies?

# %% [markdown]
# ## Question2:
#
# For $ i,j \in [1, 10]$, consider the following $10 \times 10$ matrix construct:
#
# a) For i = j:\
# $$A(i,j) = i^2 + j^2$$
#
# b) For i = j +1:\
# $$A(i,j) = 2 * (i +1)^2 + j^2$$
#
# c) For i +1 = j:\
# $$A(i,j) = i^2 + (j +1)^2$$
#
# d) The rest elements are zero
#
# Consider a vector $b$ such that, for $ i \in [1, 10]$ :
# $$b(i) = i /2.0$$
#
# **2a) [3 points]** For a given matrix A and a vector b, implement the Conjugate Gradient Method as taught in class, **without any matrix storage** to solve the Ax = b system and obtain the solution vector $x$.
#
# **2b) [0.5 points]** Verify the obatined result (in part 2a) with Numpy's module np.linalg.solve(). [**Note:** You can store matrix only for this part (2b) to use np.linalg.solve()]
#
# **2c) [0.5 points]** Use Scipy's module for Conjugate Gradient Method to solve given system $Ax = b$ and verify the obtained result with part (2a).
